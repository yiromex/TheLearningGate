# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# Mounted at /drive

# %% [markdown]
# a. Extraer la información del archivo.

# %%
import pandas as pd
vaccs = pd.read_csv('/drive/My Drive/Colab Notebooks/country_vaccinations.csv')

# %% [markdown]
# b. Mostrar la estructura y tipos de datos de cada columna para identificar qué operaciones puedes realizar con cada una de ellas, asegurándote que las columnas con fechas sean del tipo datetime64.

# %%
vaccs['date'] = pd.to_datetime(vaccs['date'])
vaccs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86512 entries, 0 to 86511
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Unnamed: 0                           86512 non-null  int64
#  1   country                              86512 non-null  object
#  2   iso_code                             86512 non-null  object
#  3   date                                 86512 non-null  datetime64[ns]
#  4   total_vaccinations                   43607 non-null  float64
#  5   people_vaccinated                    41294 non-null  float64
#  6   people_fully_vaccinated              38802 non-null  float64
#  7   daily_vaccinations_raw               35362 non-null  float64
#  8   daily_vaccinations                   86213 non-null  float64
#  9   total_vaccinations_per_hundred       43607 non-null  float64
#  10  people_vaccinated_per_hundred        41294 non-null  float64
#  11  people_fully_vaccinated_per_hundred  38802 non-null  float64
#  12  daily_vaccinations_per_million       86213 non-null  float64
#  13  vaccines                             86512 non-null  object
#  14  source_name                          86512 non-null  object
#  15  source_website                       86512 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(1), object(5)
# memory usage: 10.6+ MB

# %% [markdown]
# c. Determinar la cantidad de vacunas aplicadas de cada compañía (con base en cómo lo reporta cada país en la columna vaccines).
#
# *La informacion en el archivo country_vaccinations no contiene el detalle de cual vacuna se utilizo para inocular, sino todas las disponibles.*

# %%
vaccs[['vaccines','daily_vaccinations']].groupby('vaccines').sum()
# Out:
#                                                     daily_vaccinations
# vaccines
# Abdala, Johnson&Johnson, Oxford/AstraZeneca, Pf...           9616160.0
# Abdala, Moderna, Oxford/AstraZeneca, Pfizer/Bio...         201816053.0
# Abdala, Sinopharm/Beijing, Sinovac, Soberana02,...          37861146.0
# Abdala, Soberana Plus, Soberana02                           33802957.0
# COVIran Barekat, Covaxin, FAKHRAVAC, Oxford/Ast...         146357015.0
# ...                                                                ...
# Pfizer/BioNTech, Sinovac, Turkovac                         147484328.0
# Pfizer/BioNTech, Sputnik V                                     68643.0
# QazVac, Sinopharm/Beijing, Sputnik V                        20891256.0
# Sinopharm/Beijing                                             893824.0
# Sinopharm/Beijing, Sputnik V                                14398697.0
#
# [84 rows x 1 columns]

# %% [markdown]
# d. Obtener la cantidad de vacunas aplicadas en todo el mundo.
#
# *El ultimo registro de cada pais contiene el total de vacunas aplicadas por pais.*

# %%
totalporpais = vaccs[['country', 'total_vaccinations']].groupby('country').max()
print(totalporpais['total_vaccinations'].sum())
# Out:
# 11383441962.0

# %% [markdown]
# e. Calcular el promedio de vacunas aplicadas por país.

# %%
vaccs[['country','daily_vaccinations']].groupby('country').mean()
# Out:
#                    daily_vaccinations
# country
# Afghanistan              14610.681934
# Albania                   6276.210046
# Algeria                  33904.356436
# Andorra                    367.716019
# Angola                   44821.457584
# ...                               ...
# Wales                    15518.411765
# Wallis and Futuna           33.886486
# Yemen                     2556.115756
# Zambia                    9649.805158
# Zimbabwe                 21669.066832
#
# [223 rows x 1 columns]

# %% [markdown]
# f. Determinar la cantidad de vacunas aplicadas el día 29/01/21 en todo el mundo

# %%
print(vaccs.loc[vaccs['date']=='01-29-2021','daily_vaccinations'].sum())
# Out:
# 4884052.0

# %% [markdown]
# g. Crear un dataframe nuevo denominado conDiferencias que contenga los datos originales y una columna derivada (diferencias) con las diferencias de aplicación entre las columnas daily_vaccinations y daily_vaccinations_raw.

# %%
conDiferencias = vaccs.copy()
conDiferencias['diferencias'] = conDiferencias['daily_vaccinations'] - conDiferencias['daily_vaccinations_raw']

# %% [markdown]
# h. Obtener el período de tiempo entre el registro con fecha más reciente y el registro con fecha más antigua.

# %%
delta = vaccs['date'].max() - vaccs['date'].min()
print(delta)
# Out:
# 482 days 00:00:00

# %% [markdown]
# i. Crear un dataframe nuevo denominado conCantidad que contenga los datos originales y una columna derivada (canVac) con la cantidad de vacunas utilizadas cada día (usar la columna vaccines y separar por el carácter /).
#
# *Utilizando el caracter / en vez de la coma , no proporcionara el dato correcto correspondiente al conteo de las posibles vacunas utilizadas. La diagonal indica una colaboracion.*

# %%
conCantidad = vaccs.copy()
conCantidad['canVac'] = conCantidad['vaccines'].str.split('/').str.len()
conCantidad.tail()
# Out:
#        Unnamed: 0   country iso_code       date  total_vaccinations  \
# 86507       86507  Zimbabwe      ZWE 2022-03-25           8691642.0
# 86508       86508  Zimbabwe      ZWE 2022-03-26           8791728.0
# 86509       86509  Zimbabwe      ZWE 2022-03-27           8845039.0
# 86510       86510  Zimbabwe      ZWE 2022-03-28           8934360.0
# 86511       86511  Zimbabwe      ZWE 2022-03-29           9039729.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 86507          4814582.0                3473523.0                139213.0
# 86508          4886242.0                3487962.0                100086.0
# 86509          4918147.0                3493763.0                 53311.0
# 86510          4975433.0                3501493.0                 89321.0
# 86511          5053114.0                3510256.0                105369.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 86507             69579.0                           57.59
# 86508             83429.0                           58.25
# 86509             90629.0                           58.61
# 86510            100614.0                           59.20
# 86511            103751.0                           59.90
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 86507                          31.90                                23.02
# 86508                          32.38                                23.11
# 86509                          32.59                                23.15
# 86510                          32.97                                23.20
# 86511                          33.48                                23.26
#
#        daily_vaccinations_per_million  \
# 86507                          4610.0
# 86508                          5528.0
# 86509                          6005.0
# 86510                          6667.0
# 86511                          6874.0
#
#                                                 vaccines         source_name  \
# 86507  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
# 86508  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
# 86509  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
# 86510  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
# 86511  Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac...  Ministry of Health
#
#                                           source_website  canVac
# 86507  https://www.arcgis.com/home/webmap/viewer.html...       3
# 86508  https://www.arcgis.com/home/webmap/viewer.html...       3
# 86509  https://www.arcgis.com/home/webmap/viewer.html...       3
# 86510  https://www.arcgis.com/home/webmap/viewer.html...       3
# 86511  https://www.arcgis.com/home/webmap/viewer.html...       3

# %% [markdown]
# j. Generar un dataframe denominado antes20 con todos los registros que se hayan realizado antes del 20 de diciembre de 2020.

# %%
antes20 = vaccs.query('date < "12-20-2020"')
antes20.tail()
# Out:
#        Unnamed: 0        country iso_code       date  total_vaccinations  \
# 82362       82362  United States      USA 2020-12-15             84638.0
# 82363       82363  United States      USA 2020-12-16            244549.0
# 82364       82364  United States      USA 2020-12-17            517161.0
# 82365       82365  United States      USA 2020-12-18            933551.0
# 82366       82366  United States      USA 2020-12-19           1115437.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 82362            76984.0                   6281.0                 49771.0
# 82363           231496.0                   6757.0                159911.0
# 82364           496980.0                   7507.0                272612.0
# 82365           904656.0                   8718.0                416390.0
# 82366          1082608.0                   9778.0                181886.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 82362             27175.0                            0.03
# 82363             71420.0                            0.07
# 82364            121718.0                            0.16
# 82365            180653.0                            0.28
# 82366            180858.0                            0.34
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 82362                           0.02                                  0.0
# 82363                           0.07                                  0.0
# 82364                           0.15                                  0.0
# 82365                           0.27                                  0.0
# 82366                           0.33                                  0.0
#
#        daily_vaccinations_per_million  \
# 82362                            82.0
# 82363                           215.0
# 82364                           367.0
# 82365                           544.0
# 82366                           545.0
#
#                                         vaccines  \
# 82362  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 82363  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 82364  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 82365  Johnson&Johnson, Moderna, Pfizer/BioNTech
# 82366  Johnson&Johnson, Moderna, Pfizer/BioNTech
#
#                                       source_name  \
# 82362  Centers for Disease Control and Prevention
# 82363  Centers for Disease Control and Prevention
# 82364  Centers for Disease Control and Prevention
# 82365  Centers for Disease Control and Prevention
# 82366  Centers for Disease Control and Prevention
#
#                                           source_website
# 82362  https://data.cdc.gov/Vaccinations/COVID-19-Vac...
# 82363  https://data.cdc.gov/Vaccinations/COVID-19-Vac...
# 82364  https://data.cdc.gov/Vaccinations/COVID-19-Vac...
# 82365  https://data.cdc.gov/Vaccinations/COVID-19-Vac...
# 82366  https://data.cdc.gov/Vaccinations/COVID-19-Vac...

# %% [markdown]
# k. Obtener un dataframe denominado pfizer con todos los registros donde se haya utilizado la vacuna Pfizer.

# %%
pfizer = vaccs[vaccs['vaccines'].str.contains('pfizer',case=False)]
pfizer.tail()
# Out:
#        Unnamed: 0 country  iso_code       date  total_vaccinations  \
# 85069       85069   Wales  OWID_WLS 2022-03-24           6921195.0
# 85070       85070   Wales  OWID_WLS 2022-03-25           6923298.0
# 85071       85071   Wales  OWID_WLS 2022-03-26           6923706.0
# 85072       85072   Wales  OWID_WLS 2022-03-27           6925183.0
# 85073       85073   Wales  OWID_WLS 2022-03-28           6927437.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 85069          2526832.0                2397677.0                  1756.0
# 85070          2527100.0                2398097.0                  2103.0
# 85071          2527184.0                2398322.0                   408.0
# 85072          2528051.0                2398676.0                  1477.0
# 85073          2528664.0                2399341.0                  2254.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 85069              1705.0                          218.33
# 85070              1667.0                          218.40
# 85071              1519.0                          218.41
# 85072              1505.0                          218.46
# 85073              1609.0                          218.53
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 85069                          79.71                                75.64
# 85070                          79.72                                75.65
# 85071                          79.72                                75.66
# 85072                          79.75                                75.67
# 85073                          79.77                                75.69
#
#        daily_vaccinations_per_million  \
# 85069                           538.0
# 85070                           526.0
# 85071                           479.0
# 85072                           475.0
# 85073                           508.0
#
#                                            vaccines  \
# 85069  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 85070  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 85071  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 85072  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# 85073  Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
#
#                             source_name  \
# 85069  Government of the United Kingdom
# 85070  Government of the United Kingdom
# 85071  Government of the United Kingdom
# 85072  Government of the United Kingdom
# 85073  Government of the United Kingdom
#
#                                           source_website
# 85069  https://coronavirus.data.gov.uk/details/vaccin...
# 85070  https://coronavirus.data.gov.uk/details/vaccin...
# 85071  https://coronavirus.data.gov.uk/details/vaccin...
# 85072  https://coronavirus.data.gov.uk/details/vaccin...
# 85073  https://coronavirus.data.gov.uk/details/vaccin...

# %% [markdown]
# l. Almacenar los dataframes generados (conDiferencias, conCantidad, antes20 y pfizer) en un archivo de Excel denominado resultadosReto.xlsx, donde cada dataframe ocupe una hoja diferente. Se recomienda ver la documentación de pd.ExcelWriter.

# %%
with pd.ExcelWriter('/drive/My Drive/Colab Notebooks/resultadosReto.xlsx') as writer:
    conDiferencias.to_excel(writer,sheet_name="conDiferencias")
    conCantidad.to_excel(writer,sheet_name='conCantidad')
    antes20.to_excel(writer,sheet_name='antes20')
    pfizer.to_excel(writer, sheet_name='pfizer')
